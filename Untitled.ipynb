# %%
from gcp_client import *
GCP = GCPAuth("./gcp_secrets")
creds = GCP.creds
gdrive_client = GDriveClient(creds)

# %%
gdrive_client.delete_object("1jDfwaRFEzRqx1KaEwZpB6NJDRs_yFJnh")
